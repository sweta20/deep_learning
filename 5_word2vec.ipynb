# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
#   print([reverse_dictionary[bi] for bi in buffer])

  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      print([reverse_dictionary[bi] for bi in targets_to_avoid])
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
#     print([reverse_dictionary[bi] for bi in buffer])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# ['the']
# ['the', 'of']
# ['the']
# ['the', 'UNK']
# ['the']
# ['the', 'of']
# ['the']
# ['the', 'UNK']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
# ['of']
# ['of', 'the']
# ['of', 'the', 'UNK']
# ['of', 'the', 'UNK', 'and']
# ['of']
# ['of', 'and']
# ['of', 'and', 'one']
# ['of', 'and', 'one', 'UNK']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.867810
# Nearest to not: predicting, ais, wedded, grosbeak, lio, stara, astor, take,
# Nearest to it: certification, shows, valence, contemporaries, auxiliaries, cbd, hydrofoil, ta,
# Nearest to has: astrologer, dbu, aperture, confounded, boasting, syndicalist, invests, urey,
# Nearest to can: diana, dusty, renowned, miriam, coordinate, fully, preeminence, perennial,
# Nearest to who: oversaw, flames, unflattering, kinds, thief, purest, blocker, rensselaer,
# Nearest to in: fondation, niches, quickest, rsha, mri, messianic, pontus, potentials,
# Nearest to world: teletype, trimester, dur, hostility, throne, rescuing, haka, appears,
# Nearest to also: australia, internment, qazaqstan, toponyms, achish, giacometti, predominant, wargame,
# Nearest to time: hadrian, numidia, meatballwiki, judicious, livingstone, interplay, microcomputer, reacting,
# Nearest to than: possessions, amarna, kickoffs, integrator, deutscher, sgml, nonsensical, tashfin,
# Nearest to at: cbd, lise, sanskrit, merina, sopra, binomial, friesian, allows,
# Nearest to by: consist, atone, jealously, mingus, yak, casimir, photosensitive, reconcile,
# Nearest to eight: bloomsbury, cardinals, weekdays, dag, einhard, unequivocally, taichi, eckert,
# Nearest to were: recognition, spaceflights, cryo, cass, pubns, kinetics, iskra, bilaterally,
# Nearest to two: synapses, temptations, turnbull, continuations, dopant, flavors, archaeoastronomy, ko,
# Nearest to years: brainfuck, hooking, targaryen, syncopation, motilal, cacao, propped, dakini,
# Average loss at step 2000: 4.356137
# Average loss at step 4000: 3.864131
# Average loss at step 6000: 3.787328
# Average loss at step 8000: 3.687962
# Average loss at step 10000: 3.616184
# Nearest to not: it, they, generally, there, also, wedded, who, we,
# Nearest to it: he, this, there, they, not, which, she, still,
# Nearest to has: had, was, have, is, invests, dbu, undertakings, aalen,
# Nearest to can: may, would, mmx, could, instinct, will, subtree, confounding,
# Nearest to who: he, which, flames, they, eternal, not, also, it,
# Nearest to in: of, at, on, with, hendrick, from, applicants, bodleian,
# Nearest to world: dur, trimester, teletype, hostility, throne, appears, tripping, volga,
# Nearest to also: often, which, qazaqstan, not, she, oppenheimer, mulcahy, who,
# Nearest to time: hadrian, athabasca, wire, eon, know, microcomputer, thymine, lucas,
# Nearest to than: or, gaseous, auckland, sgml, kickoffs, angilbert, tashfin, gott,
# Nearest to at: in, on, atlantic, from, during, predominates, rem, thread,
# Nearest to by: subjugating, was, with, from, maximization, into, puddle, gurion,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to were: are, was, have, jules, fur, is, wacky, trombones,
# Nearest to two: three, four, five, seven, six, eight, nine, one,
# Nearest to years: wrapper, assassination, brainfuck, nicomedia, short, slidell, servant, targaryen,
# Average loss at step 12000: 3.602913
# Average loss at step 14000: 3.572330
# Average loss at step 16000: 3.410726
# Average loss at step 18000: 3.454679
# Average loss at step 20000: 3.540972
# Nearest to not: generally, also, it, uphill, still, to, you, seals,
# Nearest to it: he, there, this, she, they, which, not, also,
# Nearest to has: had, have, was, is, invests, aalen, cancel, single,
# Nearest to can: may, would, could, will, might, must, mmx, should,
# Nearest to who: he, which, also, they, pandemics, it, she, benzodiazepine,
# Nearest to in: at, on, within, and, with, of, during, threads,
# Nearest to world: dur, trimester, throne, teletype, hostility, compressible, livestock, lincoln,
# Nearest to also: often, who, which, not, now, sometimes, it, then,
# Nearest to time: hadrian, coincide, know, way, wire, lassa, thymine, athabasca,
# Nearest to than: or, tashfin, louise, deutscher, expensive, angilbert, gaseous, warrant,
# Nearest to at: in, term, through, from, during, atlantic, using, on,
# Nearest to by: were, be, subjugating, was, into, with, for, been,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to were: are, was, have, had, be, is, by, fur,
# Nearest to two: three, four, five, six, seven, eight, zero, one,
# Nearest to years: assassination, goalkeepers, nicomedia, days, collett, tax, wrapper, servant,
# Average loss at step 22000: 3.499186
# Average loss at step 24000: 3.488690
# Average loss at step 26000: 3.479976
# Average loss at step 28000: 3.481961
# Average loss at step 30000: 3.504266
# Nearest to not: generally, they, still, it, blasting, futuna, hb, uphill,
# Nearest to it: he, there, she, this, they, which, also, not,
# Nearest to has: had, have, is, was, dbu, invests, tsang, nigerian,
# Nearest to can: may, could, would, will, might, should, must, cannot,
# Nearest to who: he, they, also, she, pandemics, benzodiazepine, it, and,
# Nearest to in: on, at, during, of, and, from, within, between,
# Nearest to world: trimester, throne, dur, hostility, teletype, largest, kibo, algerian,
# Nearest to also: often, sometimes, now, which, already, who, it, they,
# Nearest to time: hadrian, way, period, coincide, ruler, know, eon, thymine,
# Nearest to than: or, much, louise, tashfin, minting, expensive, cryptology, angilbert,
# Nearest to at: in, during, on, interbreeding, after, rem, through, atlantic,
# Nearest to by: subjugating, was, under, with, maximization, from, been, were,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to were: are, was, had, have, is, streamlined, those, these,
# Nearest to two: four, three, one, six, five, seven, eight, nine,
# Nearest to years: days, goalkeepers, assassination, people, corinthian, nicomedia, wrapper, months,
# Average loss at step 32000: 3.502381
# Average loss at step 34000: 3.494281
# Average loss at step 36000: 3.458299
# Average loss at step 38000: 3.304755
# Average loss at step 40000: 3.427323
# Nearest to not: they, it, generally, uphill, famines, futuna, transpired, still,
# Nearest to it: he, there, she, they, this, still, which, not,
# Nearest to has: had, have, was, is, invests, tsang, biometric, since,
# Nearest to can: may, could, will, would, should, might, must, shall,
# Nearest to who: he, also, which, she, they, both, often, affirming,
# Nearest to in: of, from, and, within, during, with, for, to,
# Nearest to world: hostility, trimester, dur, throne, u, teletype, kibo, tough,
# Nearest to also: often, which, sometimes, now, who, actually, still, already,
# Nearest to time: way, coincide, period, hadrian, year, eon, know, ruler,
# Nearest to than: or, much, cryptology, coffey, turbocharged, expensive, louise, tashfin,
# Nearest to at: during, on, interbreeding, predominates, esse, in, loser, through,
# Nearest to by: from, subjugating, was, as, with, be, when, predictive,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to were: are, was, have, had, these, being, streamlined, be,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to years: days, months, goalkeepers, assassination, wrapper, year, casualties, airborne,
# Average loss at step 42000: 3.427709
# Average loss at step 44000: 3.454524
# Average loss at step 46000: 3.451435
# Average loss at step 48000: 3.351598
# Average loss at step 50000: 3.383102
# Nearest to not: generally, now, uphill, never, it, they, hb, vaccinations,
# Nearest to it: he, she, there, this, they, still, schoolgirl, now,
# Nearest to has: had, have, was, is, travels, invests, tsang, smoother,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to who: he, which, also, she, eric, eventually, both, not,
# Nearest to in: during, on, from, since, within, and, between, under,
# Nearest to world: trimester, hostility, dur, u, kibo, throne, teletype, tarot,
# Nearest to also: now, which, often, sometimes, actually, who, still, mostly,
# Nearest to time: period, way, day, athabasca, year, ruler, eon, hateful,
# Nearest to than: or, but, cryptology, much, andamanese, coffey, turbocharged, gott,
# Nearest to at: during, near, interbreeding, esse, in, unfairly, on, rollout,
# Nearest to by: through, under, subjugating, maximization, tray, monolith, minuet, simulates,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to were: are, have, was, be, had, streamlined, those, stray,
# Nearest to two: three, four, six, one, seven, five, eight, zero,
# Nearest to years: days, months, year, people, goalkeepers, assassination, sse, times,
# Average loss at step 52000: 3.433467
# Average loss at step 54000: 3.425685
# Average loss at step 56000: 3.438984
# Average loss at step 58000: 3.394288
# Average loss at step 60000: 3.392482
# Nearest to not: still, generally, they, uphill, who, we, hb, serbians,
# Nearest to it: he, she, there, this, they, still, which, annum,
# Nearest to has: had, have, was, is, cyclist, tsang, moreover, rockstar,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to who: he, she, now, also, which, both, not, eric,
# Nearest to in: within, during, since, of, including, among, at, until,
# Nearest to world: dur, trimester, hostility, throne, kibo, largest, post, tough,
# Nearest to also: now, often, sometimes, still, mostly, actually, who, generally,
# Nearest to time: period, way, eon, athabasca, year, hateful, advantage, conjunct,
# Nearest to than: or, but, cryptology, much, and, objectivist, tashfin, turbocharged,
# Nearest to at: in, during, near, atlantic, under, predominates, leiden, exemplify,
# Nearest to by: subjugating, through, was, maximization, drags, with, calibers, fossil,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to were: are, was, had, have, those, been, although, be,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to years: days, months, year, times, goalkeepers, sse, hours, people,
# Average loss at step 62000: 3.240650
# Average loss at step 64000: 3.254938
# Average loss at step 66000: 3.400964
# Average loss at step 68000: 3.390640
# Average loss at step 70000: 3.360898
# Nearest to not: still, uphill, generally, now, usually, musik, always, actually,
# Nearest to it: he, she, there, this, they, still, basileus, naomi,
# Nearest to has: had, have, is, was, since, galeon, smoother, cyclist,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to who: he, she, eric, affirming, they, both, which, now,
# Nearest to in: within, during, for, using, on, from, through, stormy,
# Nearest to world: dur, u, trimester, vietnam, kibo, credo, post, temple,
# Nearest to also: now, often, still, sometimes, never, actually, which, generally,
# Nearest to time: period, way, athabasca, hateful, case, reign, place, hermes,
# Nearest to than: but, cryptology, or, and, coffey, much, andamanese, mutual,
# Nearest to at: near, during, predominates, tofu, cremation, on, allows, interbreeding,
# Nearest to by: through, be, subjugating, hartford, seifert, without, from, aquarists,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to were: are, have, was, had, be, those, racer, spamming,
# Nearest to two: three, four, six, seven, five, one, eight, nine,
# Nearest to years: days, months, year, hours, sse, times, goalkeepers, centuries,
# Average loss at step 72000: 3.369480
# Average loss at step 74000: 3.342530
# Average loss at step 76000: 3.314991
# Average loss at step 78000: 3.353060
# Average loss at step 80000: 3.375528
# Nearest to not: still, uphill, serbians, always, we, actually, generally, they,
# Nearest to it: he, she, there, this, they, we, disconnected, naomi,
# Nearest to has: had, have, is, was, gives, rockstar, includes, since,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to who: he, they, she, often, affirming, blish, eric, which,
# Nearest to in: during, within, on, until, between, from, at, stormy,
# Nearest to world: dur, u, trimester, hostility, exhausting, temple, kibo, throne,
# Nearest to also: now, often, still, sometimes, never, which, mostly, actually,
# Nearest to time: period, day, way, reign, year, hateful, pharsalus, stated,
# Nearest to than: but, cryptology, while, much, andamanese, or, objectivist, tags,
# Nearest to at: in, cremation, near, tofu, during, narrates, on, tuples,
# Nearest to by: shatt, subjugating, through, maximization, from, with, tray, pln,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to were: are, had, was, have, those, be, these, been,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to years: days, months, year, times, hours, decades, minutes, weeks,
# Average loss at step 82000: 3.403444
# Average loss at step 84000: 3.405662
# Average loss at step 86000: 3.392015
# Average loss at step 88000: 3.347018
# Average loss at step 90000: 3.366962
# Nearest to not: still, uphill, we, actually, now, serbians, also, generally,
# Nearest to it: he, she, there, they, this, naomi, probably, disconnected,
# Nearest to has: had, have, is, was, gives, makes, having, since,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to who: he, affirming, often, which, now, she, also, blish,
# Nearest to in: during, within, until, with, at, tanker, between, of,
# Nearest to world: kibo, temple, exhausting, dur, post, hostility, throne, alchemists,
# Nearest to also: now, still, often, which, never, sometimes, actually, mostly,
# Nearest to time: period, day, year, reign, way, hateful, athabasca, hermes,
# Nearest to than: cryptology, objectivist, mutual, turbocharged, without, tags, radiohead, coffey,
# Nearest to at: during, near, under, on, interbreeding, in, atlantic, cremation,
# Nearest to by: through, subjugating, shatt, against, without, maximization, while, for,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to were: are, had, have, was, while, those, these, stray,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to years: days, months, year, decades, hours, centuries, times, minutes,
# Average loss at step 92000: 3.399206
# Average loss at step 94000: 3.249897
# Average loss at step 96000: 3.358625
# Average loss at step 98000: 3.239363
# Average loss at step 100000: 3.355096
# Nearest to not: still, never, generally, always, uphill, serbians, considered, now,
# Nearest to it: he, she, this, there, they, which, often, naomi,
# Nearest to has: had, have, is, was, gives, smoother, contains, since,
# Nearest to can: could, may, must, would, will, should, cannot, might,
# Nearest to who: he, she, which, now, also, and, often, that,
# Nearest to in: during, within, throughout, on, at, from, until, of,
# Nearest to world: dur, exhausting, kibo, hostility, algerian, temple, u, throne,
# Nearest to also: still, now, often, never, sometimes, actually, which, who,
# Nearest to time: year, period, athabasca, survivors, day, way, reign, hermes,
# Nearest to than: or, andamanese, much, while, cryptology, objectivist, slightly, panthera,
# Nearest to at: during, on, in, near, interbreeding, after, under, allows,
# Nearest to by: when, through, involving, maximization, minuet, sharpened, including, shatt,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to were: are, was, have, these, those, had, stray, gees,
# Nearest to two: five, three, six, four, seven, eight, one, zero,
# Nearest to years: days, months, year, hours, decades, times, centuries, goalkeepers,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 
  batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1,2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch]) 
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed,1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.922392
# Nearest to he: probation, cystitis, while, fatigue, chronically, auditum, slowly, retaliate,
# Nearest to years: acm, computations, pickling, estampie, bekenstein, beauharnais, tighter, guarneri,
# Nearest to may: sharing, bayes, swansea, leaky, sayed, pipelined, minting, stressing,
# Nearest to two: failures, sarawak, fgm, loeb, eucharistic, critiques, separator, spouses,
# Nearest to with: pressurized, lagrange, handball, sheryl, nnhilde, ingredients, sociologist, embargo,
# Nearest to b: exceeds, cruising, dynamics, jourdan, plunder, fortress, frozen, sardaukar,
# Nearest to was: somalis, hurd, michelob, depopulated, snowmobiles, cricketing, arcologies, disinfectant,
# Nearest to would: esperantists, mauss, madonna, ncs, quartered, lactate, kernel, jab,
# Nearest to about: gaps, cnr, superclass, been, mitigating, kantian, lukas, tasman,
# Nearest to after: insomnia, parodied, buggery, calamine, wop, hazards, encountered, butcher,
# Nearest to only: bsi, bendis, transactions, lax, conscription, labeled, del, chronicon,
# Nearest to such: rushed, bruges, telegram, norad, trajan, kinsey, cardinals, suisse,
# Nearest to used: icp, margin, apollonius, leg, rpg, llywelyn, elites, syrup,
# Nearest to some: shenouda, mortuary, longer, exclaims, erm, clausius, ssc, josephine,
# Nearest to first: moloch, lowercase, barns, field, alu, faulty, vinnie, trademark,
# Nearest to they: clearances, eicher, rondo, signalled, coprime, dartmouth, aroused, unicameral,
# Average loss at step 2000: 6.473972
# Average loss at step 4000: 4.706570
# Average loss at step 6000: 3.911649
# Average loss at step 8000: 3.848968
# Average loss at step 10000: 3.596360
# Nearest to he: it, she, they, who, coppola, invoked, realization, rand,
# Nearest to years: roamed, centerline, decades, acadia, promotion, year, theotokos, days,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to two: three, five, nine, four, seven, ordaining, one, accusation,
# Nearest to with: mohandas, archives, after, in, premiership, gaba, limewire, before,
# Nearest to b: d, fashion, viability, electricity, editorship, dexter, dagny, ethnocentric,
# Nearest to was: resins, bradley, eight, atomic, mass, ep, physics, model,
# Nearest to would: may, will, could, can, should, might, must, cannot,
# Nearest to about: partita, rammed, unstated, user, tiger, funniest, confine, eprint,
# Nearest to after: before, centauri, bent, three, sort, when, ep, mass,
# Nearest to only: tangerine, economists, detector, fingers, aground, bachchan, budd, it,
# Nearest to such: well, far, known, rinks, breeding, poorest, aneurin, combines,
# Nearest to used: referred, targaryen, mommu, considered, known, rationale, publications, found,
# Nearest to some: many, several, hausa, oldies, those, any, these, various,
# Nearest to first: production, before, during, amid, ep, fei, novel, same,
# Nearest to they: we, these, he, csd, signalling, there, desolation, you,
# Average loss at step 12000: 4.138517
# Average loss at step 14000: 3.519010
# Average loss at step 16000: 3.553954
# Average loss at step 18000: 3.432988
# Average loss at step 20000: 3.320840
# Nearest to he: she, it, they, who, devises, there, nic, prosthetic,
# Nearest to years: months, however, minister, disraeli, bradley, days, ep, prime,
# Nearest to may: can, would, will, should, could, might, must, to,
# Nearest to two: three, seven, s, six, bradley, zero, years, michigan,
# Nearest to with: between, debugger, ngc, when, prohibits, bandits, superconductivity, windowing,
# Nearest to b: d, c, bamberg, punitive, donut, eisenman, payment, graciously,
# Nearest to was: is, were, became, are, matisse, codepoint, tyrant, disinfectant,
# Nearest to would: will, may, could, should, must, can, might, did,
# Nearest to about: however, therefore, bradley, disraeli, over, minister, cor, derby,
# Nearest to after: before, when, michelson, during, chimneys, sustaining, honshu, unveils,
# Nearest to only: first, rosetta, namespace, prepared, no, seyss, topple, all,
# Nearest to such: well, known, downing, far, described, many, juno, boleyn,
# Nearest to used: considered, known, referred, found, available, given, written, called,
# Nearest to some: many, several, these, various, different, those, any, diameters,
# Nearest to first: only, last, same, next, second, final, during, pamphilus,
# Nearest to they: we, he, there, you, these, pearce, caso, passages,
# Average loss at step 22000: 3.513760
# Average loss at step 24000: 3.366622
# Average loss at step 26000: 3.332453
# Average loss at step 28000: 3.348715
# Average loss at step 30000: 3.266017
# Nearest to he: she, it, they, brothers, tomlinson, kawasaki, who, claimant,
# Nearest to years: decades, days, months, year, centuries, times, minutes, roamed,
# Nearest to may: would, could, will, can, might, must, should, did,
# Nearest to two: six, zero, five, gurney, eight, one, three, conversely,
# Nearest to with: between, including, against, bashar, by, freaks, reichswehr, among,
# Nearest to b: k, d, interstates, m, f, mathrm, hans, p,
# Nearest to was: is, became, were, becomes, are, being, had, has,
# Nearest to would: will, could, may, might, can, must, should, did,
# Nearest to about: spitting, from, audiogalaxy, epitomized, on, concerning, tiger, unscathed,
# Nearest to after: before, during, when, next, since, aldehyde, feb, within,
# Nearest to only: dyke, boarded, barlow, soso, yet, million, annoying, bristol,
# Nearest to such: well, described, juno, known, these, clad, regarded, follows,
# Nearest to used: considered, seen, called, intended, referred, found, known, formed,
# Nearest to some: many, several, both, all, these, lu, most, those,
# Nearest to first: second, last, next, final, same, earliest, following, original,
# Nearest to they: we, you, there, he, she, til, imo, chaco,
# Average loss at step 32000: 3.055613
# Average loss at step 34000: 3.250277
# Average loss at step 36000: 3.243973
# Average loss at step 38000: 3.212507
# Average loss at step 40000: 3.198062
# Nearest to he: she, it, they, tomlinson, never, oint, who, sorbian,
# Nearest to years: days, decades, months, centuries, times, year, minutes, theotokos,
# Nearest to may: would, can, will, should, must, could, might, cannot,
# Nearest to two: three, five, zero, four, six, every, glitch, eight,
# Nearest to with: between, bashar, against, trichloride, when, cuttlefish, droll, oc,
# Nearest to b: d, r, p, h, four, seven, treads, bamberg,
# Nearest to was: is, were, became, are, being, had, remains, pros,
# Nearest to would: will, could, should, may, might, can, must, did,
# Nearest to about: spitting, tiger, concerning, over, audiogalaxy, yields, regarding, epitomized,
# Nearest to after: before, during, since, until, when, through, for, despite,
# Nearest to only: still, usually, million, seyss, namespace, conifer, disappears, caxton,
# Nearest to such: well, described, follows, far, seen, result, known, regarded,
# Nearest to used: considered, seen, intended, referred, written, known, available, found,
# Nearest to some: many, several, various, numerous, both, covens, these, most,
# Nearest to first: last, second, final, next, same, original, third, earliest,
# Nearest to they: you, we, he, she, there, til, haider, caso,
# Average loss at step 42000: 3.260762
# Average loss at step 44000: 3.202881
# Average loss at step 46000: 3.172421
# Average loss at step 48000: 3.090339
# Average loss at step 50000: 3.085370
# Nearest to he: she, it, they, dove, damaging, who, there, oint,
# Nearest to years: decades, year, days, months, minutes, centuries, times, hours,
# Nearest to may: can, would, could, must, should, might, will, cannot,
# Nearest to two: three, five, six, zero, four, nabba, several, cocaine,
# Nearest to with: between, requires, bashar, chesterton, duffy, hotspots, initials, makes,
# Nearest to b: d, akh, diacritics, adonijah, standby, kn, unheated, cannabis,
# Nearest to was: is, were, became, being, becomes, are, matisse, remained,
# Nearest to would: could, may, might, can, should, will, must, cannot,
# Nearest to about: yields, regarding, tiger, samadhi, spitting, patience, why, possessor,
# Nearest to after: before, during, without, when, guernica, following, at, honshu,
# Nearest to only: always, hermas, disappears, still, till, no, chassis, isdb,
# Nearest to such: well, follows, described, seen, known, same, opposed, far,
# Nearest to used: considered, seen, found, referred, intended, available, known, presented,
# Nearest to some: many, all, several, various, these, numerous, certain, most,
# Nearest to first: last, next, final, second, original, third, same, earliest,
# Nearest to they: we, you, he, there, she, til, minos, signalling,
# Average loss at step 52000: 3.149511
# Average loss at step 54000: 3.119747
# Average loss at step 56000: 2.950540
# Average loss at step 58000: 3.037259
# Average loss at step 60000: 3.062985
# Nearest to he: she, it, they, oint, tomlinson, who, griffith, spector,
# Nearest to years: months, decades, days, centuries, times, minutes, weeks, year,
# Nearest to may: can, might, should, must, would, could, will, cannot,
# Nearest to two: three, four, eight, five, nine, six, zero, unfalsifiable,
# Nearest to with: between, against, among, including, minstrels, hitchhikers, using, bashar,
# Nearest to b: d, h, hans, leq, neill, p, c, timepieces,
# Nearest to was: is, became, were, becomes, has, had, are, being,
# Nearest to would: will, could, might, must, should, may, can, cannot,
# Nearest to about: regarding, epitomized, complicate, on, spitting, concerning, interstates, ascertaining,
# Nearest to after: before, during, despite, when, since, later, following, for,
# Nearest to only: still, no, conifer, actually, last, brac, prem, pomona,
# Nearest to such: well, seen, follows, regarded, opposed, described, far, known,
# Nearest to used: seen, referred, available, known, considered, intended, described, found,
# Nearest to some: many, several, all, numerous, various, most, certain, both,
# Nearest to first: last, next, second, final, arleigh, beginning, earliest, tories,
# Nearest to they: we, you, she, he, there, longfellow, hk, programs,
# Average loss at step 62000: 3.031930
# Average loss at step 64000: 2.945773
# Average loss at step 66000: 2.963006
# Average loss at step 68000: 3.022149
# Average loss at step 70000: 3.039463
# Nearest to he: she, it, they, who, tomlinson, veyron, paulo, tischendorf,
# Nearest to years: months, decades, days, year, minutes, weeks, centuries, times,
# Nearest to may: could, might, must, can, should, would, will, cannot,
# Nearest to two: three, zero, five, six, seven, four, eight, acker,
# Nearest to with: between, bashar, including, minstrels, by, antiwar, debugger, among,
# Nearest to b: nk, rebound, engineer, uruguayan, kpd, bau, jet, fiber,
# Nearest to was: is, were, becomes, became, has, are, had, remains,
# Nearest to would: will, could, may, might, must, should, can, did,
# Nearest to about: regarding, on, concerning, spitting, unicef, sumter, wrangler, azimuth,
# Nearest to after: before, during, following, when, for, despite, honshu, since,
# Nearest to only: barlow, always, hermas, stretch, till, finnegans, iraqis, strongest,
# Nearest to such: well, follows, seen, described, known, regarded, result, viewed,
# Nearest to used: intended, seen, available, referred, required, considered, described, applied,
# Nearest to some: many, several, certain, various, all, numerous, both, most,
# Nearest to first: last, second, next, earliest, third, arleigh, original, best,
# Nearest to they: we, you, he, there, she, it, longfellow, these,
# Average loss at step 72000: 2.969038
# Average loss at step 74000: 2.888288
# Average loss at step 76000: 3.015072
# Average loss at step 78000: 3.022762
# Average loss at step 80000: 2.869808
# Nearest to he: she, it, they, who, there, originally, once, tomlinson,
# Nearest to years: decades, months, days, minutes, year, centuries, weeks, times,
# Nearest to may: can, could, might, should, will, would, must, cannot,
# Nearest to two: three, five, microbiology, six, zero, syndicalism, underwing, medians,
# Nearest to with: between, among, contra, superconductivity, dismiss, debugger, duffy, oc,
# Nearest to b: sacagawea, sinning, mathbf, l, freiherr, voles, kw, oaxaca,
# Nearest to was: is, were, becomes, has, newly, are, became, remains,
# Nearest to would: will, could, might, must, should, may, can, cannot,
# Nearest to about: concerning, regarding, fuzes, breeder, over, domed, bcg, plebiscite,
# Nearest to after: before, during, following, when, until, despite, without, within,
# Nearest to only: always, concerti, tipped, necessarily, amyl, actually, hermas, no,
# Nearest to such: well, follows, described, far, seen, opposed, regarded, result,
# Nearest to used: intended, available, referred, described, known, seen, applied, considered,
# Nearest to some: many, certain, several, various, both, all, most, these,
# Nearest to first: last, next, second, arleigh, earliest, original, third, same,
# Nearest to they: we, you, he, she, there, longfellow, urls, others,
# Average loss at step 82000: 2.954479
# Average loss at step 84000: 2.907351
# Average loss at step 86000: 2.932909
# Average loss at step 88000: 2.965116
# Average loss at step 90000: 2.856053
# Nearest to he: she, it, they, initially, oint, cassette, werke, tomlinson,
# Nearest to years: decades, days, months, centuries, year, minutes, weeks, hours,
# Nearest to may: can, might, should, will, must, could, cannot, would,
# Nearest to two: three, six, four, five, one, introns, seven, several,
# Nearest to with: among, between, plus, blooming, antiwar, without, distinctly, requires,
# Nearest to b: partial, mod, doric, treads, sacagawea, cnr, subclass, commas,
# Nearest to was: is, were, became, becomes, are, had, newly, being,
# Nearest to would: could, should, will, might, must, may, can, cannot,
# Nearest to about: indium, eindhoven, memoir, genetics, compounds, panda, children, summand,
# Nearest to after: before, during, despite, within, following, when, since, until,
# Nearest to only: always, no, all, it, discarded, recife, actually, bookkeeping,
# Nearest to such: well, follows, result, described, opposed, far, regarded, seen,
# Nearest to used: intended, required, seen, designed, available, considered, referred, defined,
# Nearest to some: many, most, none, several, various, numerous, particularly, eindhoven,
# Nearest to first: last, next, second, earliest, original, final, best, arleigh,
# Nearest to they: we, he, you, she, there, longfellow, it, bentham,
# Average loss at step 92000: 2.909776
# Average loss at step 94000: 2.897837
# Average loss at step 96000: 2.716543
# Average loss at step 98000: 2.482908
# Average loss at step 100000: 2.730216
# Nearest to he: she, they, it, initially, cassette, tomlinson, stereotyping, dove,
# Nearest to years: decades, months, days, year, centuries, hours, minutes, weeks,
# Nearest to may: might, can, must, could, should, cannot, would, will,
# Nearest to two: three, four, five, seven, six, millimeter, zero, guattari,
# Nearest to with: between, minstrels, among, by, excluding, requires, dismiss, antiwar,
# Nearest to b: d, endosymbiotic, inordinate, conjunctions, amsterdam, dupuis, marbles, creatively,
# Nearest to was: is, became, were, are, remained, had, becomes, matisse,
# Nearest to would: could, will, might, should, must, can, cannot, may,
# Nearest to about: concerning, regarding, through, arthur, spitting, over, plus, comprehensive,
# Nearest to after: before, following, despite, without, during, upon, later, abyssinia,
# Nearest to only: first, always, last, yet, necessarily, techs, no, tans,
# Nearest to such: well, seen, whole, follows, result, viewed, breeding, winer,
# Nearest to used: intended, referred, designed, seen, added, applied, done, required,
# Nearest to some: many, several, various, this, certain, both, these, numerous,
# Nearest to first: last, next, second, earliest, best, third, only, greatest,
# Nearest to they: we, he, you, there, she, til, longfellow, dancers,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
